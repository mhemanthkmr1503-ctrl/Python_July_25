# %%
from matplotlib import pyplot as plt

# %%
X = [1,2,3,4,5]
Y = [1,4,9,16,25]
Y.reverse()

plt.plot(X,Y)
plt.xlabel("No of Years")
plt.ylabel("Total Revenue")
plt.title("Insights about the revenue")
# Out:
# Text(0.5, 1.0, 'Insights about the revenue')

# %%
X = [1,2,3,4,5]
Products = ["Grocery", "Car", "Home Essentials", "Skin Care", "Snaks & Beverages"]   

plt.bar(Products, X)
# Out:
# <BarContainer object of 5 artists>
