# %%
import pandas as pd

# %%
df = pd.read_csv("iris.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 154 entries, 0 to 153
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  153 non-null    float64
#  1   sepal.width   153 non-null    float64
#  2   petal.length  153 non-null    float64
#  3   petal.width   153 non-null    float64
#  4   variety       154 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.1+ KB

# %%
df.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    153.000000   153.000000    153.000000   153.000000
# mean       5.850327     3.056863      3.787582     1.213725
# std        0.822074     0.434342      1.760320     0.761928
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
df.tail()
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 149           5.9          3.0           5.1          1.8  Virginica
# 150           6.3          2.5           5.0          1.9  Virginica
# 151           6.5          3.0           5.2          2.0  Virginica
# 152           6.2          3.4           5.4          2.3  Virginica
# 153           5.9          3.0           5.1          1.8  Virginica

# %%
df.head(6)
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# 5           5.4          3.9           1.7          0.4  Setosa

# %%
# Location -> Label based Location -> loc
# ILocation -> Index based Location -> iloc

df.loc[1,'sepal.length']
# Out:
# np.float64(4.9)

# %%
df.iloc[5,3]
# Out:
# np.float64(0.4)

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 149           5.9          3.0           5.1          1.8  Virginica
# 150           6.3          2.5           5.0          1.9  Virginica
# 151           6.5          3.0           5.2          2.0  Virginica
# 152           6.2          3.4           5.4          2.3  Virginica
# 153           5.9          3.0           5.1          1.8  Virginica
#
# [154 rows x 5 columns]

# %%
df[~((df['variety'] == 'Setosa') | (df['variety'] == 'Virginica')) & (df['sepal.length'] >= 6.5)]
# Out:
#     sepal.length  sepal.width  petal.length  petal.width     variety
# 50           7.0          3.2           4.7          1.4  Versicolor
# 52           6.9          3.1           4.9          1.5  Versicolor
# 54           6.5          2.8           4.6          1.5  Versicolor
# 58           6.6          2.9           4.6          1.3  Versicolor
# 65           6.7          3.1           4.4          1.4  Versicolor
# 75           6.6          3.0           4.4          1.4  Versicolor
# 76           6.8          2.8           4.8          1.4  Versicolor
# 77           6.7          3.0           5.0          1.7  Versicolor
# 86           6.7          3.1           4.7          1.5  Versicolor

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Column Selection
(df[['petal.length', 'sepal.length', 'variety']])
# Out:
#      petal.length  sepal.length    variety
# 0             1.4           5.1     Setosa
# 1             1.4           4.9     Setosa
# 2             1.3           4.7     Setosa
# 3             1.5           4.6     Setosa
# 4             1.4           5.0     Setosa
# ..            ...           ...        ...
# 149           5.1           5.9  Virginica
# 150           5.0           6.3  Virginica
# 151           5.2           6.5  Virginica
# 152           5.4           6.2  Virginica
# 153           5.1           5.9  Virginica
#
# [154 rows x 3 columns]

# %%
df['petal.length'].min()
# Out:
# np.float64(1.0)

# %%
df['petal.length'].max()
# Out:
# np.float64(6.9)

# %%
df['petal.length'].count()
# Out:
# np.int64(153)

# %%
df['petal.length'].mean()
# Out:
# np.float64(3.787581699346405)

# %%
df['petal.length'].median()
# Out:
# np.float64(4.4)

# %%
df['petal.length'].mode()
# Out:
# 0    1.4
# 1    1.5
# Name: petal.length, dtype: float64

# %%
df['petal.length'].sum()
# Out:
# np.float64(579.5)

# %%
df['petal.length'].value_counts()
# Out:
# petal.length
# 1.4    13
# 1.5    13
# 5.1     9
# 4.5     8
# 1.3     7
# 1.6     7
# 5.6     6
# 4.0     5
# 5.0     5
# 4.7     5
# 1.7     4
# 4.8     4
# 4.4     4
# 4.2     4
# 4.9     4
# 5.2     3
# 3.9     3
# 5.4     3
# 5.7     3
# 4.1     3
# 6.1     3
# 5.8     3
# 4.6     3
# 5.5     3
# 6.7     2
# 1.2     2
# 1.9     2
# 3.5     2
# 3.3     2
# 5.3     2
# 4.3     2
# 5.9     2
# 6.0     2
# 1.0     1
# 1.1     1
# 3.7     1
# 3.8     1
# 3.6     1
# 3.0     1
# 6.3     1
# 6.6     1
# 6.9     1
# 6.4     1
# Name: count, dtype: int64

# %%
df['petal.length'].std()
# Out:
# np.float64(1.7603199567661552)

# %%
df.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    153.000000   153.000000    153.000000   153.000000
# mean       5.850327     3.056863      3.787582     1.213725
# std        0.822074     0.434342      1.760320     0.761928
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.sort_values(by='sepal.length', ascending=False)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 131           7.9          3.8           6.4          2.0  Virginica
# 122           7.7          2.8           6.7          2.0  Virginica
# 118           7.7          2.6           6.9          2.3  Virginica
# 117           7.7          3.8           6.7          NaN  Virginica
# 135           7.7          3.0           6.1          2.3  Virginica
# ..            ...          ...           ...          ...        ...
# 38            4.4          3.0           1.3          0.2     Setosa
# 8             4.4          2.9           1.4          0.2     Setosa
# 42            4.4          3.2           1.3          0.2     Setosa
# 13            4.3          3.0           1.1          0.1     Setosa
# 123           NaN          2.7           4.9          1.8  Virginica
#
# [154 rows x 5 columns]

# %%
df[['sepal.length', 'variety']].groupby(by='variety').std()
# Out:
#             sepal.length
# variety
# Setosa          0.352490
# Versicolor      0.516171
# Virginica       0.626634

# %%
# Null Analysis

df.isnull().sum()
# Out:
# sepal.length    1
# sepal.width     1
# petal.length    1
# petal.width     1
# variety         0
# dtype: int64

# %%
df.dropna().count()
# Out:
# sepal.length    150
# sepal.width     150
# petal.length    150
# petal.width     150
# variety         150
# dtype: int64

# %%
df.drop_duplicates().count()
# Out:
# sepal.length    148
# sepal.width     148
# petal.length    148
# petal.width     148
# variety         149
# dtype: int64

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 149           5.9          3.0           5.1          1.8  Virginica
# 150           6.3          2.5           5.0          1.9  Virginica
# 151           6.5          3.0           5.2          2.0  Virginica
# 152           6.2          3.4           5.4          2.3  Virginica
# 153           5.9          3.0           5.1          1.8  Virginica
#
# [154 rows x 5 columns]

# %%
df = df.drop(index=[1,2,3,4])

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 5             5.4          3.9           1.7          0.4     Setosa
# 6             4.6          3.4           1.4          0.3     Setosa
# 7             5.0          3.4           1.5          0.2     Setosa
# 8             4.4          2.9           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 149           5.9          3.0           5.1          1.8  Virginica
# 150           6.3          2.5           5.0          1.9  Virginica
# 151           6.5          3.0           5.2          2.0  Virginica
# 152           6.2          3.4           5.4          2.3  Virginica
# 153           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df.fillna(56)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 5             5.4          3.9           1.7          0.4     Setosa
# 6             4.6          3.4           1.4          0.3     Setosa
# 7             5.0          3.4           1.5          0.2     Setosa
# 8             4.4          2.9           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 149           5.9          3.0           5.1          1.8  Virginica
# 150           6.3          2.5           5.0          1.9  Virginica
# 151           6.5          3.0           5.2          2.0  Virginica
# 152           6.2          3.4           5.4          2.3  Virginica
# 153           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
from matplotlib import pyplot as plt


plt.hist(df['petal.length'])
# Out:
# (array([33., 13.,  0.,  3.,  8., 26., 30., 20., 11.,  5.]),
#  array([1.  , 1.59, 2.18, 2.77, 3.36, 3.95, 4.54, 5.13, 5.72, 6.31, 6.9 ]),
#  <BarContainer object of 10 artists>)
